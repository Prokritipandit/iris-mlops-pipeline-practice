# %%
# !pip install pandas pyarrow
import pandas as pd
from datetime import datetime
import os
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# --- CONFIG ---
# Make sure your new augmented data is in the data/ folder
AUGMENTED_DATA_FILE = "data/iris_augmented.csv" 

# Define output paths
FEATURE_DATA_PATH = "data/iris_features.parquet"
GROUND_TRUTH_PATH = "data/iris_ground_truth.csv"
# --- END CONFIG ---

# Load your source data
df = pd.read_csv(AUGMENTED_DATA_FILE)

# Convert timestamp strings to datetime objects (CRITICAL)
# This assumes your timestamps are in the format shown in your prompt
df['event_timestamp'] = pd.to_datetime(df['event_timestamp'])
df['created_timestamp'] = pd.to_datetime(df['created_timestamp'])

# Ensure data directory exists
os.makedirs("data", exist_ok=True)

print(f"Loaded {len(df)} rows.")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 11
#       7 GROUND_TRUTH_PATH = "data/iris_ground_truth.csv"
#       8 # --- END CONFIG ---
#       9
#      10 # Load your source data
# ---> 11 df = pd.read_csv(AUGMENTED_DATA_FILE)
#      13 # Convert timestamp strings to datetime objects (CRITICAL)
#      14 # This assumes your timestamps are in the format shown in your prompt
#      15 df['event_timestamp'] = pd.to_datetime(df['event_timestamp'])
#
# ...

# %%
# !pwd
